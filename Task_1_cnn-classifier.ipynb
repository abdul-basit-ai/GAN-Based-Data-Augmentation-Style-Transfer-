# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np

# 1. Define transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),   # Resize to fit ResNet input
    transforms.ToTensor()
])

# 2. Load datasets (change root as needed)
train_dataset = datasets.ImageFolder(root="/kaggle/input/vision-project-data/Newdata/Train", transform=transform)
test_dataset = datasets.ImageFolder(root="/kaggle/input/vision-project-data/Newdata/Test", transform=transform)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)
# 3. Model, loss, optimizer
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = ResNet50(num_classes=2, ).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# 4. Training loop
num_epochs = 50
train_losses = []
train_accuracies = []

for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0
    correct = 0
    total = 0

    for batch in train_loader:
        images, labels = batch
        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    avg_loss = epoch_loss / len(train_loader)
    acc = 100 * correct / total
    train_losses.append(avg_loss)
    train_accuracies.append(acc)

    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}, Accuracy: {acc:.2f}%")

# 5. Plot train accuracy and loss
plt.figure(figsize=(12,5))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Train Accuracy', color='green')
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.title("Training Accuracy")
plt.legend()
plt.show()

# 6. Evaluation on test set + confusion matrix
model.eval()
y_true = []
y_pred = []

with torch.no_grad():
    for batch in test_loader:
        images, labels = batch
        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)

        y_true.extend(labels.cpu().numpy())
        y_pred.extend(predicted.cpu().numpy())

# Accuracy
correct = np.sum(np.array(y_true) == np.array(y_pred))
test_acc = 100 * correct / len(y_true)
print(f"Test Accuracy: {test_acc:.2f}%")

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=train_dataset.classes, yticklabels=train_dataset.classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Epoch [1/50], Loss: 0.1115, Accuracy: 96.34%
# Epoch [2/50], Loss: 0.1403, Accuracy: 97.56%
# Epoch [3/50], Loss: 1.9684, Accuracy: 97.56%
# Epoch [4/50], Loss: 0.3581, Accuracy: 92.68%
# Epoch [5/50], Loss: 0.0098, Accuracy: 100.00%
# Epoch [6/50], Loss: 0.0067, Accuracy: 100.00%
# Epoch [7/50], Loss: 0.7649, Accuracy: 92.68%
# Epoch [8/50], Loss: 0.2708, Accuracy: 92.68%
# Epoch [9/50], Loss: 0.1919, Accuracy: 95.12%
# Epoch [10/50], Loss: 0.6980, Accuracy: 95.12%
# Epoch [11/50], Loss: 0.0621, Accuracy: 97.56%
# Epoch [12/50], Loss: 0.0241, Accuracy: 98.78%
# Epoch [13/50], Loss: 0.6069, Accuracy: 87.80%
# Epoch [14/50], Loss: 0.4928, Accuracy: 97.56%
# Epoch [15/50], Loss: 0.1622, Accuracy: 97.56%
# Epoch [16/50], Loss: 0.3128, Accuracy: 82.93%
# Epoch [17/50], Loss: 0.0208, Accuracy: 100.00%
# Epoch [18/50], Loss: 0.0207, Accuracy: 100.00%
# Epoch [19/50], Loss: 0.0596, Accuracy: 97.56%
# Epoch [20/50], Loss: 0.0042, Accuracy: 100.00%
# Epoch [21/50], Loss: 0.7774, Accuracy: 92.68%
# Epoch [22/50], Loss: 0.0184, Accuracy: 98.78%
# Epoch [23/50], Loss: 0.4376, Accuracy: 97.56%
# Epoch [24/50], Loss: 0.1880, Accuracy: 90.24%
# Epoch [25/50], Loss: 0.0163, Accuracy: 100.00%
# Epoch [26/50], Loss: 0.0294, Accuracy: 100.00%
# Epoch [27/50], Loss: 0.4225, Accuracy: 97.56%
# Epoch [28/50], Loss: 0.0624, Accuracy: 96.34%
# Epoch [29/50], Loss: 0.3413, Accuracy: 95.12%
# Epoch [30/50], Loss: 0.4673, Accuracy: 90.24%
# Epoch [31/50], Loss: 0.1565, Accuracy: 93.90%
# Epoch [32/50], Loss: 0.1115, Accuracy: 96.34%
# Epoch [33/50], Loss: 0.0352, Accuracy: 100.00%
# Epoch [34/50], Loss: 0.4065, Accuracy: 97.56%
# Epoch [35/50], Loss: 0.0164, Accuracy: 100.00%
# Epoch [36/50], Loss: 0.1077, Accuracy: 93.90%
# Epoch [37/50], Loss: 0.1652, Accuracy: 98.78%
# Epoch [38/50], Loss: 0.0891, Accuracy: 95.12%
# Epoch [39/50], Loss: 0.0287, Accuracy: 100.00%
# Epoch [40/50], Loss: 0.0678, Accuracy: 98.78%
# Epoch [41/50], Loss: 0.0546, Accuracy: 98.78%
# Epoch [42/50], Loss: 0.0646, Accuracy: 97.56%
# Epoch [43/50], Loss: 0.0170, Accuracy: 100.00%
# Epoch [44/50], Loss: 0.0153, Accuracy: 100.00%
# Epoch [45/50], Loss: 0.0069, Accuracy: 100.00%
# Epoch [46/50], Loss: 0.0099, Accuracy: 100.00%
# Epoch [47/50], Loss: 0.6430, Accuracy: 97.56%
# Epoch [48/50], Loss: 0.0146, Accuracy: 100.00%
# Epoch [49/50], Loss: 0.0445, Accuracy: 98.78%
# Epoch [50/50], Loss: 0.0441, Accuracy: 97.56%
# Test Accuracy: 43.90%

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np

# 1. Define transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),   # Resize to fit ResNet input
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalization for pretrained models
])

# 2. Load datasets (change root as needed)
train_dataset = datasets.ImageFolder(root="/kaggle/input/vision-project-data/Newdata/Train", transform=transform)
test_dataset = datasets.ImageFolder(root="/kaggle/input/vision-project-data/Newdata/Test", transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# 3. Use Pretrained ResNet50 model from torchvision
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Load the pretrained ResNet50 model
model = models.resnet50(pretrained=True)

# Modify the final fully connected layer for your number of classes (2 classes in your case)
model.fc = nn.Linear(model.fc.in_features, 2)

# Move model to device
model = model.to(device)

# Optionally, freeze the layers if you want to fine-tune only the final layers
for param in model.parameters():
    param.requires_grad = False

# Unfreeze the final fully connected layer (this is usually the layer we fine-tune)
for param in model.fc.parameters():
    param.requires_grad = True

# 4. Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.fc.parameters(), lr=0.002)

# 5. Training loop
num_epochs = 50
train_losses = []
train_accuracies = []

for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0
    correct = 0
    total = 0

    for batch in train_loader:
        images, labels = batch
        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    avg_loss = epoch_loss / len(train_loader)
    acc = 100 * correct / total
    train_losses.append(avg_loss)
    train_accuracies.append(acc)

    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}, Accuracy: {acc:.2f}%")

# 6. Plot train accuracy and loss
plt.figure(figsize=(12,5))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Train Accuracy', color='green')
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.title("Training Accuracy")
plt.legend()
plt.show()

# 7. Evaluation on test set + confusion matrix
model.eval()
y_true = []
y_pred = []

with torch.no_grad():
    for batch in test_loader:
        images, labels = batch
        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)

        y_true.extend(labels.cpu().numpy())
        y_pred.extend(predicted.cpu().numpy())

# Accuracy
correct = np.sum(np.array(y_true) == np.array(y_pred))
test_acc = 100 * correct / len(y_true)
print(f"Test Accuracy: {test_acc:.2f}%")

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=train_dataset.classes, yticklabels=train_dataset.classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 215MB/s]
# Epoch [1/50], Loss: 0.9690, Accuracy: 46.34%
# Epoch [2/50], Loss: 0.6991, Accuracy: 50.00%
# Epoch [3/50], Loss: 0.3043, Accuracy: 97.56%
# Epoch [4/50], Loss: 0.3457, Accuracy: 76.83%
# Epoch [5/50], Loss: 0.1412, Accuracy: 100.00%
# Epoch [6/50], Loss: 0.2284, Accuracy: 95.12%
# Epoch [7/50], Loss: 0.1280, Accuracy: 98.78%
# Epoch [8/50], Loss: 0.1141, Accuracy: 98.78%
# Epoch [9/50], Loss: 0.0866, Accuracy: 98.78%
# Epoch [10/50], Loss: 0.1245, Accuracy: 97.56%
# Epoch [11/50], Loss: 0.0493, Accuracy: 100.00%
# Epoch [12/50], Loss: 0.0518, Accuracy: 100.00%
# Epoch [13/50], Loss: 0.0571, Accuracy: 100.00%
# Epoch [14/50], Loss: 0.0263, Accuracy: 100.00%
# Epoch [15/50], Loss: 0.0328, Accuracy: 100.00%
# Epoch [16/50], Loss: 0.0224, Accuracy: 100.00%
# Epoch [17/50], Loss: 0.0222, Accuracy: 100.00%
# Epoch [18/50], Loss: 0.0281, Accuracy: 100.00%
# Epoch [19/50], Loss: 0.0194, Accuracy: 100.00%
# Epoch [20/50], Loss: 0.0257, Accuracy: 100.00%
# Epoch [21/50], Loss: 0.0234, Accuracy: 100.00%
# Epoch [22/50], Loss: 0.0273, Accuracy: 100.00%
# Epoch [23/50], Loss: 0.0175, Accuracy: 100.00%
# Epoch [24/50], Loss: 0.0175, Accuracy: 100.00%
# Epoch [25/50], Loss: 0.0187, Accuracy: 100.00%
# Epoch [26/50], Loss: 0.0374, Accuracy: 100.00%
# Epoch [27/50], Loss: 0.0131, Accuracy: 100.00%
# Epoch [28/50], Loss: 0.0142, Accuracy: 100.00%
# Epoch [29/50], Loss: 0.0146, Accuracy: 100.00%
# Epoch [30/50], Loss: 0.0121, Accuracy: 100.00%
# Epoch [31/50], Loss: 0.0302, Accuracy: 100.00%
# Epoch [32/50], Loss: 0.0106, Accuracy: 100.00%
# Epoch [33/50], Loss: 0.0216, Accuracy: 100.00%
# Epoch [34/50], Loss: 0.0113, Accuracy: 100.00%
# Epoch [35/50], Loss: 0.0132, Accuracy: 100.00%
# Epoch [36/50], Loss: 0.0136, Accuracy: 100.00%
# Epoch [37/50], Loss: 0.0086, Accuracy: 100.00%
# Epoch [38/50], Loss: 0.0108, Accuracy: 100.00%
# Epoch [39/50], Loss: 0.0101, Accuracy: 100.00%
# Epoch [40/50], Loss: 0.0088, Accuracy: 100.00%
# Epoch [41/50], Loss: 0.0111, Accuracy: 100.00%
# Epoch [42/50], Loss: 0.0126, Accuracy: 100.00%
# Epoch [43/50], Loss: 0.0092, Accuracy: 100.00%
# Epoch [44/50], Loss: 0.0133, Accuracy: 100.00%
# Epoch [45/50], Loss: 0.0497, Accuracy: 98.78%
# Epoch [46/50], Loss: 0.0077, Accuracy: 100.00%
# Epoch [47/50], Loss: 0.0113, Accuracy: 100.00%
# Epoch [48/50], Loss: 0.0132, Accuracy: 100.00%
# Epoch [49/50], Loss: 0.0108, Accuracy: 100.00%
# Epoch [50/50], Loss: 0.0130, Accuracy: 100.00%
# Test Accuracy: 78.05%

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader, ConcatDataset, Subset
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# 1. Transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# 2. Load Train and Test datasets
train_dataset = datasets.ImageFolder(root="/kaggle/input/vision-project-data/Newdata/Train", transform=transform)
test_dataset = datasets.ImageFolder(root="/kaggle/input/vision-project-data/Newdata/Test", transform=transform)

# 3. Combine datasets
combined_dataset = ConcatDataset([train_dataset, test_dataset])
class_names = train_dataset.classes

# 4. K-Fold CV setup
k_folds = 4
kf = KFold(n_splits=k_folds, shuffle=True, random_state=42)
fold_accuracies = []

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
num_epochs = 50
batch_size = 32

# 5. Start K-Fold loop
for fold, (all_idx, _) in enumerate(kf.split(combined_dataset)):
    print(f"\n========== Fold {fold+1} ==========")

    # 60% training, 40% testing split within fold
    np.random.shuffle(all_idx)
    total_len = len(all_idx)
    train_len = int(0.5 * total_len)
    train_idx = all_idx[:train_len]
    test_idx = all_idx[train_len:]

    train_subset = Subset(combined_dataset, train_idx)
    test_subset = Subset(combined_dataset, test_idx)

    train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_subset, batch_size=batch_size, shuffle=False)

    # Class distribution function
    def get_distribution(indices):
        label_list = [combined_dataset[i][1] for i in indices]
        values, counts = np.unique(label_list, return_counts=True)
        return dict(zip([class_names[i] for i in values], counts))

    print("Train distribution:", get_distribution(train_idx))
    print("Test distribution:", get_distribution(test_idx))

    # Load and modify ResNet50
    model = models.resnet50(pretrained=False)
    model.fc = nn.Linear(model.fc.in_features, len(class_names))
    model = model.to(device)

    # Freeze all layers except final FC
    for param in model.parameters():
        param.requires_grad = False
    for param in model.fc.parameters():
        param.requires_grad = True

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.fc.parameters(), lr=0.002)

    train_losses = []
    train_accuracies = []

    # Training
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0
        correct = 0
        total = 0

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item() * labels.size(0)
            _, predicted = torch.max(outputs.data, 1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

        avg_loss = epoch_loss / total
        train_acc = 100 * correct / total

        train_losses.append(avg_loss)
        train_accuracies.append(train_acc)
        print(f"Epoch {epoch+1}/{num_epochs}, Loss: {avg_loss:.4f}, Train Accuracy: {train_acc:.2f}%")

    # Testing
    model.eval()
    y_true, y_pred = [], []

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(predicted.cpu().numpy())

    acc = 100 * np.sum(np.array(y_true) == np.array(y_pred)) / len(y_true)
    fold_accuracies.append(acc)
    print(f"Fold {fold+1} Test Accuracy: {acc:.2f}%")

    # Confusion Matrix
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.title(f"Confusion Matrix - Fold {fold+1}")
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.show()

    # Plot Loss and Accuracy Curve for this fold
    plt.figure(figsize=(10, 4))

    plt.subplot(1, 2, 1)
    plt.plot(range(1, num_epochs+1), train_losses, label='Training Loss')
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title(f"Training Loss - Fold {fold+1}")
    plt.grid(True)

    plt.subplot(1, 2, 2)
    plt.plot(range(1, num_epochs+1), train_accuracies, label='Training Accuracy', color='green')
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy (%)")
    plt.title(f"Training Accuracy - Fold {fold+1}")
    plt.grid(True)

    plt.tight_layout()
    plt.show()

# Summary of all folds
print("\n========== Cross-Validation Summary ==========")
for i, acc in enumerate(fold_accuracies):
    print(f"Fold {i+1} Accuracy: {acc:.2f}%")
print(f"Average Accuracy: {np.mean(fold_accuracies):.2f}%")
# Out:
# ========== Fold 1 ==========
# Train distribution: {'Cow': 29, 'Horse': 32}
# Test distribution: {'Cow': 33, 'Horse': 29}
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Epoch 1/50, Loss: 0.6910, Train Accuracy: 60.66%
# Epoch 2/50, Loss: 1.1262, Train Accuracy: 55.74%
# Epoch 3/50, Loss: 1.0624, Train Accuracy: 47.54%
# Epoch 4/50, Loss: 0.8608, Train Accuracy: 55.74%
# Epoch 5/50, Loss: 0.6865, Train Accuracy: 63.93%
# Epoch 6/50, Loss: 0.8404, Train Accuracy: 55.74%
# Epoch 7/50, Loss: 0.6652, Train Accuracy: 60.66%
# Epoch 8/50, Loss: 0.7499, Train Accuracy: 65.57%
# Epoch 9/50, Loss: 0.6107, Train Accuracy: 62.30%
# Epoch 10/50, Loss: 0.6421, Train Accuracy: 59.02%
# Epoch 11/50, Loss: 0.6066, Train Accuracy: 68.85%
# Epoch 12/50, Loss: 0.5829, Train Accuracy: 65.57%
# Epoch 13/50, Loss: 0.6139, Train Accuracy: 63.93%
# Epoch 14/50, Loss: 0.5610, Train Accuracy: 68.85%
# Epoch 15/50, Loss: 0.5997, Train Accuracy: 70.49%
# Epoch 16/50, Loss: 0.5510, Train Accuracy: 68.85%
# Epoch 17/50, Loss: 0.6378, Train Accuracy: 70.49%
# Epoch 18/50, Loss: 0.6981, Train Accuracy: 63.93%
# Epoch 19/50, Loss: 0.5854, Train Accuracy: 67.21%
# Epoch 20/50, Loss: 0.6563, Train Accuracy: 65.57%
# Epoch 21/50, Loss: 0.5551, Train Accuracy: 73.77%
# Epoch 22/50, Loss: 0.5382, Train Accuracy: 77.05%
# Epoch 23/50, Loss: 0.5978, Train Accuracy: 63.93%
# Epoch 24/50, Loss: 0.5868, Train Accuracy: 62.30%
# Epoch 25/50, Loss: 0.5505, Train Accuracy: 68.85%
# Epoch 26/50, Loss: 0.5507, Train Accuracy: 70.49%
# Epoch 27/50, Loss: 0.5191, Train Accuracy: 77.05%
# Epoch 28/50, Loss: 0.5170, Train Accuracy: 75.41%
# Epoch 29/50, Loss: 0.5302, Train Accuracy: 72.13%
# Epoch 30/50, Loss: 0.5415, Train Accuracy: 73.77%
# Epoch 31/50, Loss: 0.5227, Train Accuracy: 72.13%
# Epoch 32/50, Loss: 0.4899, Train Accuracy: 78.69%
# Epoch 33/50, Loss: 0.4956, Train Accuracy: 70.49%
# Epoch 34/50, Loss: 0.4748, Train Accuracy: 80.33%


# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader, ConcatDataset, Subset
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# 1. Transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# 2. Load Train and Test datasets
train_dataset = datasets.ImageFolder(root="/kaggle/input/vision-project-data/Newdata/Train", transform=transform)
test_dataset = datasets.ImageFolder(root="/kaggle/input/vision-project-data/Newdata/Test", transform=transform)

# 3. Combine datasets
combined_dataset = ConcatDataset([train_dataset, test_dataset])
class_names = train_dataset.classes

# 4. K-Fold CV setup
k_folds = 4
kf = KFold(n_splits=k_folds, shuffle=True, random_state=42)
fold_accuracies = []

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
num_epochs = 50
batch_size = 32

# 5. Start K-Fold loop
for fold, (all_idx, _) in enumerate(kf.split(combined_dataset)):
    print(f"\n========== Fold {fold+1} ==========")

    # 60% training, 40% testing split within fold
    np.random.shuffle(all_idx)
    total_len = len(all_idx)
    train_len = int(0.5 * total_len)
    train_idx = all_idx[:train_len]
    test_idx = all_idx[train_len:]

    train_subset = Subset(combined_dataset, train_idx)
    test_subset = Subset(combined_dataset, test_idx)

    train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_subset, batch_size=batch_size, shuffle=False)

    # Class distribution function
    def get_distribution(indices):
        label_list = [combined_dataset[i][1] for i in indices]
        values, counts = np.unique(label_list, return_counts=True)
        return dict(zip([class_names[i] for i in values], counts))

    print("Train distribution:", get_distribution(train_idx))
    print("Test distribution:", get_distribution(test_idx))

    # Load and modify ResNet50
    model = models.resnet50(pretrained=True)
    model.fc = nn.Linear(model.fc.in_features, len(class_names))
    model = model.to(device)

    # Freeze all layers except final FC
    for param in model.parameters():
        param.requires_grad = False
    for param in model.fc.parameters():
        param.requires_grad = True

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.fc.parameters(), lr=0.002)

    train_losses = []
    train_accuracies = []

    # Training
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0
        correct = 0
        total = 0

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item() * labels.size(0)
            _, predicted = torch.max(outputs.data, 1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

        avg_loss = epoch_loss / total
        train_acc = 100 * correct / total

        train_losses.append(avg_loss)
        train_accuracies.append(train_acc)
        print(f"Epoch {epoch+1}/{num_epochs}, Loss: {avg_loss:.4f}, Train Accuracy: {train_acc:.2f}%")

    # Testing
    model.eval()
    y_true, y_pred = [], []

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(predicted.cpu().numpy())

    acc = 100 * np.sum(np.array(y_true) == np.array(y_pred)) / len(y_true)
    fold_accuracies.append(acc)
    print(f"Fold {fold+1} Test Accuracy: {acc:.2f}%")

    # Confusion Matrix
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.title(f"Confusion Matrix - Fold {fold+1}")
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.show()

    # Plot Loss and Accuracy Curve for this fold
    plt.figure(figsize=(10, 4))

    plt.subplot(1, 2, 1)
    plt.plot(range(1, num_epochs+1), train_losses, label='Training Loss')
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title(f"Training Loss - Fold {fold+1}")
    plt.grid(True)

    plt.subplot(1, 2, 2)
    plt.plot(range(1, num_epochs+1), train_accuracies, label='Training Accuracy', color='green')
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy (%)")
    plt.title(f"Training Accuracy - Fold {fold+1}")
    plt.grid(True)

    plt.tight_layout()
    plt.show()

# Summary of all folds
print("\n========== Cross-Validation Summary ==========")
for i, acc in enumerate(fold_accuracies):
    print(f"Fold {i+1} Accuracy: {acc:.2f}%")
print(f"Average Accuracy: {np.mean(fold_accuracies):.2f}%")
# Out:
# ========== Fold 1 ==========
# Train distribution: {'Cow': 29, 'Horse': 32}
# Test distribution: {'Cow': 33, 'Horse': 29}
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/50, Loss: 1.1412, Train Accuracy: 34.43%
# Epoch 2/50, Loss: 0.7283, Train Accuracy: 47.54%
# Epoch 3/50, Loss: 0.7770, Train Accuracy: 50.82%
# Epoch 4/50, Loss: 0.4529, Train Accuracy: 78.69%
# Epoch 5/50, Loss: 0.4434, Train Accuracy: 63.93%
# Epoch 6/50, Loss: 0.2742, Train Accuracy: 96.72%
# Epoch 7/50, Loss: 0.2512, Train Accuracy: 93.44%
# Epoch 8/50, Loss: 0.2317, Train Accuracy: 93.44%
# Epoch 9/50, Loss: 0.1663, Train Accuracy: 98.36%
# Epoch 10/50, Loss: 0.1416, Train Accuracy: 100.00%
# Epoch 11/50, Loss: 0.1516, Train Accuracy: 100.00%
# Epoch 12/50, Loss: 0.1238, Train Accuracy: 100.00%
# Epoch 13/50, Loss: 0.1013, Train Accuracy: 100.00%
# Epoch 14/50, Loss: 0.1144, Train Accuracy: 98.36%
# Epoch 15/50, Loss: 0.0905, Train Accuracy: 100.00%
# Epoch 16/50, Loss: 0.0722, Train Accuracy: 100.00%
# Epoch 17/50, Loss: 0.0637, Train Accuracy: 100.00%
# Epoch 18/50, Loss: 0.0629, Train Accuracy: 100.00%
# Epoch 19/50, Loss: 0.0595, Train Accuracy: 100.00%
# Epoch 20/50, Loss: 0.0543, Train Accuracy: 100.00%
# Epoch 21/50, Loss: 0.0501, Train Accuracy: 100.00%
# Epoch 22/50, Loss: 0.0460, Train Accuracy: 100.00%
# Epoch 23/50, Loss: 0.0446, Train Accuracy: 100.00%
# Epoch 24/50, Loss: 0.0553, Train Accuracy: 100.00%
# Epoch 25/50, Loss: 0.0370, Train Accuracy: 100.00%
# Epoch 26/50, Loss: 0.0380, Train Accuracy: 100.00%
# Epoch 27/50, Loss: 0.0342, Train Accuracy: 100.00%
# Epoch 28/50, Loss: 0.0483, Train Accuracy: 100.00%
# Epoch 29/50, Loss: 0.0313, Train Accuracy: 100.00%
# Epoch 30/50, Loss: 0.0285, Train Accuracy: 100.00%
# Epoch 31/50, Loss: 0.0374, Train Accuracy: 100.00%
# Epoch 32/50, Loss: 0.0265, Train Accuracy: 100.00%
# Epoch 33/50, Loss: 0.0272, Train Accuracy: 100.00%
# Epoch 34/50, Loss: 0.0256, Train Accuracy: 100.00%
# Epoch 35/50, Loss: 0.0273, Train Accuracy: 100.00%
# Epoch 36/50, Loss: 0.0225, Train Accuracy: 100.00%
# Epoch 37/50, Loss: 0.0229, Train Accuracy: 100.00%
# Epoch 38/50, Loss: 0.0373, Train Accuracy: 100.00%
# Epoch 39/50, Loss: 0.0219, Train Accuracy: 100.00%
# Epoch 40/50, Loss: 0.0224, Train Accuracy: 100.00%
# Epoch 41/50, Loss: 0.0208, Train Accuracy: 100.00%
# Epoch 42/50, Loss: 0.0207, Train Accuracy: 100.00%
# Epoch 43/50, Loss: 0.0412, Train Accuracy: 100.00%
# Epoch 44/50, Loss: 0.0191, Train Accuracy: 100.00%
# Epoch 45/50, Loss: 0.0183, Train Accuracy: 100.00%
# Epoch 46/50, Loss: 0.0186, Train Accuracy: 100.00%
# Epoch 47/50, Loss: 0.0183, Train Accuracy: 100.00%
# Epoch 48/50, Loss: 0.0202, Train Accuracy: 100.00%
# Epoch 49/50, Loss: 0.0153, Train Accuracy: 100.00%
# Epoch 50/50, Loss: 0.0212, Train Accuracy: 100.00%
# Fold 1 Test Accuracy: 96.77%
# ========== Fold 2 ==========
# Train distribution: {'Cow': 30, 'Horse': 31}
# Test distribution: {'Cow': 27, 'Horse': 35}
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/50, Loss:
# Epoch 43/50, Loss: 0.0092, Train Accuracy: 100.00%
# Epoch 44/50, Loss: 0.0070, Train Accuracy: 100.00%
# Epoch 45/50, Loss: 0.0089, Train Accuracy: 100.00%
# Epoch 46/50, Loss: 0.0072, Train Accuracy: 100.00%
# Epoch 47/50, Loss: 0.0073, Train Accuracy: 100.00%
# Epoch 48/50, Loss: 0.0078, Train Accuracy: 100.00%
# Epoch 49/50, Loss: 0.0160, Train Accuracy: 100.00%
# Epoch 50/50, Loss: 0.0065, Train Accuracy: 100.00%
# Fold 3 Test Accuracy: 98.39%
# ========== Fold 4 ==========
# Train distribution: {'Cow': 34, 'Horse': 27}
# Test distribution: {'Cow': 29, 'Horse': 33}
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/50, Loss: 1.1531, Train Accuracy: 45.90%
# Epoch 2/50, Loss: 0.5996, Train Accuracy: 59.02%
# Epoch 3/50, Loss: 0.7779, Train Accuracy: 44.26%
# Epoch 4/50, Loss: 0.3692, Train Accuracy: 91.80%
# Epoch 5/50, Loss: 0.4374, Train Accuracy: 63.93%
# Epoch 6/50, Loss: 0.2894, Train Accuracy: 83.61%
# Epoch 7/50, Loss: 0.1944, Train Accuracy: 100.00%
# Epoch 8/50, Loss: 0.2390, Train Accuracy: 95.08%
# Epoch 9/50, Loss: 0.1717, Train Accuracy: 98.36%
# Epoch 10/50, Loss: 0.1219, Train Accuracy: 98.36%
# Epoch 11/50, Loss: 0.1274, Train Accuracy: 96.72%
# Epoch 12/50, Loss: 0.1134, Train Accuracy: 98.36%
# Epoch 13/50, Loss: 0.0890, Train Accuracy: 96.72%
# Epoch 14/50, Loss: 0.0632, Train Accuracy: 100.00%
# Epoch 15/50, Loss: 0.0792, Train Accuracy: 100.00%
# Epoch 16/50, Loss: 0.0639, Train Accuracy: 100.00%
# Epoch 17/50, Loss: 0.0528, Train Accuracy: 100.00%
# Epoch 18/50, Loss: 0.0464, Train Accuracy: 100.00%
# Epoch 19/50, Loss: 0.0424, Train Accuracy: 100.00%
# Epoch 20/50, Loss: 0.0388, Train Accuracy: 100.00%
# Epoch 21/50, Loss: 0.0472, Train Accuracy: 100.00%
# Epoch 22/50, Loss: 0.0340, Train Accuracy: 100.00%
# Epoch 23/50, Loss: 0.0316, Train Accuracy: 100.00%
# Epoch 24/50, Loss: 0.0412, Train Accuracy: 100.00%
# Epoch 25/50, Loss: 0.0359, Train Accuracy: 100.00%
# Epoch 26/50, Loss: 0.0318, Train Accuracy: 100.00%
# Epoch 27/50, Loss: 0.0254, Train Accuracy: 100.00%
# Epoch 28/50, Loss: 0.0284, Train Accuracy: 100.00%
# Epoch 29/50, Loss: 0.0217, Train Accuracy: 100.00%
# Epoch 30/50, Loss: 0.0228, Train Accuracy: 100.00%
# Epoch 31/50, Loss: 0.0352, Train Accuracy: 100.00%
# Epoch 32/50, Loss: 0.0272, Train Accuracy: 100.00%
# Epoch 33/50, Loss: 0.0199, Train Accuracy: 100.00%
# Epoch 34/50, Loss: 0.0259, Train Accuracy: 100.00%
# Epoch 35/50, Loss: 0.0198, Train Accuracy: 100.00%
# Epoch 36/50, Loss: 0.0202, Train Accuracy: 100.00%
# Epoch 37/50, Loss: 0.0185, Train Accuracy: 100.00%
# Epoch 38/50, Loss: 0.0169, Train Accuracy: 100.00%
# Epoch 39/50, Loss: 0.0201, Train Accuracy: 100.00%
# Epoch 40/50, Loss: 0.0185, Train Accuracy: 100.00%
# Epoch 41/50, Loss: 0.0227, Train Accuracy: 100.00%
# Epoch 42/50, Loss: 0.0191, Train Accuracy: 100.00%
# Epoch 43/50, Loss: 0.0133, Train Accuracy: 100.00%
# Epoch 44/50, Loss: 0.0150, Train Accuracy: 100.00%
# Epoch 45/50, Loss: 0.0141, Train Accuracy: 100.00%
# Epoch 46/50, Loss: 0.0146, Train Accuracy: 100.00%
# Epoch 47/50, Loss: 0.0138, Train Accuracy: 100.00%
# Epoch 48/50, Loss: 0.0277, Train Accuracy: 100.00%
# Epoch 49/50, Loss: 0.0186, Train Accuracy: 100.00%
# Epoch 50/50, Loss: 0.0171, Train Accuracy: 100.00%
# Fold 4 Test Accuracy: 98.39%
# ========== Cross-Validation Summary ==========
# Fold 1 Accuracy: 96.77%
# Fold 2 Accuracy: 100.00%
# Fold 3 Accuracy: 98.39%
# Fold 4 Accuracy: 98.39%
# Average Accuracy: 98.39%

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np

# 1. Define transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),   # Resize to fit VGG16 input
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalization for pretrained models
])

# 2. Load datasets (change root as needed)
train_dataset = datasets.ImageFolder(root="/kaggle/input/vision-project-data/Newdata/Train", transform=transform)
test_dataset = datasets.ImageFolder(root="/kaggle/input/vision-project-data/Newdata/Test", transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# 3. Use Pretrained VGG16 model from torchvision
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Load the pretrained VGG16 model
model = models.vgg16(pretrained=False)

# Modify the final fully connected layer for your number of classes (2 classes in your case)
model.classifier[6] = nn.Linear(model.classifier[6].in_features, 2)

# Move model to device
model = model.to(device)

# Optionally, freeze the layers if you want to fine-tune only the final layers
for param in model.parameters():
    param.requires_grad = False

# Unfreeze the final fully connected layer (this is usually the layer we fine-tune)
for param in model.classifier[6].parameters():
    param.requires_grad = True

# 4. Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.classifier[6].parameters(), lr=0.002)

# 5. Training loop
num_epochs = 100
train_losses = []
train_accuracies = []

for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0
    correct = 0
    total = 0

    for batch in train_loader:
        images, labels = batch
        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    avg_loss = epoch_loss / len(train_loader)
    acc = 100 * correct / total
    train_losses.append(avg_loss)
    train_accuracies.append(acc)

    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}, Accuracy: {acc:.2f}%")

# 6. Plot train accuracy and loss
plt.figure(figsize=(12,5))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Train Accuracy', color='green')
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.title("Training Accuracy")
plt.legend()
plt.show()

# 7. Evaluation on test set + confusion matrix
model.eval()
y_true = []
y_pred = []

with torch.no_grad():
    for batch in test_loader:
        images, labels = batch
        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)

        y_true.extend(labels.cpu().numpy())
        y_pred.extend(predicted.cpu().numpy())

# Accuracy
correct = np.sum(np.array(y_true) == np.array(y_pred))
test_acc = 100 * correct / len(y_true)
print(f"Test Accuracy: {test_acc:.2f}%")

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=train_dataset.classes, yticklabels=train_dataset.classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Epoch [1/100], Loss: 0.6877, Accuracy: 51.22%
# Epoch [2/100], Loss: 0.6883, Accuracy: 59.76%
# Epoch [3/100], Loss: 0.6586, Accuracy: 60.98%
# Epoch [4/100], Loss: 0.6343, Accuracy: 68.29%
# Epoch [5/100], Loss: 0.6439, Accuracy: 76.83%
# Epoch [6/100], Loss: 0.6227, Accuracy: 75.61%
# Epoch [7/100], Loss: 0.6001, Accuracy: 78.05%
# Epoch [8/100], Loss: 0.6030, Accuracy: 89.02%
# Epoch [9/100], Loss: 0.5767, Accuracy: 82.93%
# Epoch [10/100], Loss: 0.5838, Accuracy: 85.37%
# Epoch [11/100], Loss: 0.5303, Accuracy: 95.12%
# Epoch [12/100], Loss: 0.5579, Accuracy: 84.15%
# Epoch [13/100], Loss: 0.5461, Accuracy: 84.15%
# Epoch [14/100], Loss: 0.5256, Accuracy: 91.46%
# Epoch [61/100], Loss: 0.2660, Accuracy: 93.90%
# Epoch [62/100], Loss: 0.2905, Accuracy: 92.68%
# Epoch [63/100], Loss: 0.3159, Accuracy: 93.90%
# Epoch [64/100], Loss: 0.3462, Accuracy: 92.68%
# Epoch [65/100], Loss: 0.2949, Accuracy: 93.90%
# Epoch [66/100], Loss: 0.2881, Accuracy: 93.90%
# Epoch [67/100], Loss: 0.2643, Accuracy: 96.34%
# Epoch [68/100], Loss: 0.3118, Accuracy: 95.12%
# Epoch [69/100], Loss: 0.2890, Accuracy: 95.12%
# Epoch [70/100], Loss: 0.2799, Accuracy: 93.90%
# Epoch [71/100], Loss: 0.2968, Accuracy: 96.34%
# Epoch [72/100], Loss: 0.2545, Accuracy: 96.34%
# Epoch [73/100], Loss: 0.2789, Accuracy: 92.68%
# Epoch [74/100], Loss: 0.2926, Accuracy: 95.12%
# Epoch [75/100], Loss: 0.2889, Accuracy: 92.68%
# Epoch [76/100], Loss: 0.2897, Accuracy: 91.46%
# Epoch [77/100], Loss: 0.2791, Accuracy: 93.90%
# Epoch [78/100], Loss: 0.2392, Accuracy: 95.12%
# Epoch [79/100], Loss: 0.2675, Accuracy: 93.90%
# Epoch [80/100], Loss: 0.2651, Accuracy: 93.90%
# Epoch [81/100], Loss: 0.2902, Accuracy: 96.34%
# Epoch [82/100], Loss: 0.2637, Accuracy: 96.34%
# Epoch [83/100], Loss: 0.2814, Accuracy: 92.68%
# Epoch [84/100], Loss: 0.2382, Accuracy: 95.12%
# Epoch [85/100], Loss: 0.2553, Accuracy: 92.68%
# Epoch [86/100], Loss: 0.2716, Accuracy: 93.90%
# Epoch [87/100], Loss: 0.2554, Accuracy: 92.68%
# Epoch [88/100], Loss: 0.2582, Accuracy: 97.56%
# Epoch [89/100], Loss: 0.2750, Accuracy: 91.46%
# Epoch [90/100], Loss: 0.2064, Accuracy: 96.34%
# Epoch [91/100], Loss: 0.2500, Accuracy: 95.12%
# Epoch [92/100], Loss: 0.2714, Accuracy: 93.90%
# Epoch [93/100], Loss: 0.2458, Accuracy: 93.90%
# Epoch [94/100], Loss: 0.2785, Accuracy: 91.46%
# Epoch [95/100], Loss: 0.2549, Accuracy: 93.90%
# Epoch [96/100], Loss: 0.2563, Accuracy: 91.46%
# Epoch [97/100], Loss: 0.2215, Accuracy: 95.12%
# Epoch [98/100], Loss: 0.2392, Accuracy: 93.90%
# Epoch [99/100], Loss: 0.2339, Accuracy: 95.12%
# Epoch [100/100], Loss: 0.2081, Accuracy: 98.78%
# Test Accuracy: 42.68%

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np

# 1. Define transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),   # Resize to fit VGG16 input
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalization for pretrained models
])

# 2. Load datasets (change root as needed)
train_dataset = datasets.ImageFolder(root="/kaggle/input/vision-project-data/Newdata/Train", transform=transform)
test_dataset = datasets.ImageFolder(root="/kaggle/input/vision-project-data/Newdata/Test", transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# 3. Use Pretrained VGG16 model from torchvision
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Load the pretrained VGG16 model
model = models.vgg16(pretrained=True)

# Modify the final fully connected layer for your number of classes (2 classes in your case)
model.classifier[6] = nn.Linear(model.classifier[6].in_features, 2)

# Move model to device
model = model.to(device)

# Optionally, freeze the layers if you want to fine-tune only the final layers
for param in model.parameters():
    param.requires_grad = False

# Unfreeze the final fully connected layer (this is usually the layer we fine-tune)
for param in model.classifier[6].parameters():
    param.requires_grad = True

# 4. Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.classifier[6].parameters(), lr=0.002)

# 5. Training loop
num_epochs = 50
train_losses = []
train_accuracies = []

for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0
    correct = 0
    total = 0

    for batch in train_loader:
        images, labels = batch
        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    avg_loss = epoch_loss / len(train_loader)
    acc = 100 * correct / total
    train_losses.append(avg_loss)
    train_accuracies.append(acc)

    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}, Accuracy: {acc:.2f}%")

# 6. Plot train accuracy and loss
plt.figure(figsize=(12,5))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Train Accuracy', color='green')
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.title("Training Accuracy")
plt.legend()
plt.show()

# 7. Evaluation on test set + confusion matrix
model.eval()
y_true = []
y_pred = []

with torch.no_grad():
    for batch in test_loader:
        images, labels = batch
        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)

        y_true.extend(labels.cpu().numpy())
        y_pred.extend(predicted.cpu().numpy())

# Accuracy
correct = np.sum(np.array(y_true) == np.array(y_pred))
test_acc = 100 * correct / len(y_true)
print(f"Test Accuracy: {test_acc:.2f}%")

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=train_dataset.classes, yticklabels=train_dataset.classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:02<00:00, 211MB/s]
# Epoch [1/50], Loss: 0.4553, Accuracy: 69.51%
# Epoch [2/50], Loss: 0.0301, Accuracy: 98.78%
# Epoch [3/50], Loss: 0.0036, Accuracy: 100.00%
# Epoch [4/50], Loss: 0.0024, Accuracy: 100.00%
# Epoch [5/50], Loss: 0.0009, Accuracy: 100.00%
# Epoch [6/50], Loss: 0.0006, Accuracy: 100.00%
# Epoch [7/50], Loss: 0.0008, Accuracy: 100.00%
# Epoch [8/50], Loss: 0.0009, Accuracy: 100.00%
# Epoch [9/50], Loss: 0.0005, Accuracy: 100.00%
# Epoch [10/50], Loss: 0.0001, Accuracy: 100.00%
# Epoch [11/50], Loss: 0.0002, Accuracy: 100.00%
# Epoch [12/50], Loss: 0.0002, Accuracy: 100.00%
# Epoch [13/50], Loss: 0.0002, Accuracy: 100.00%
# Epoch [14/50], Loss: 0.0001, Accuracy: 100.00%
# Epoch [15/50], Loss: 0.0006, Accuracy: 100.00%
# Epoch [16/50], Loss: 0.0001, Accuracy: 100.00%
# Epoch [17/50], Loss: 0.0001, Accuracy: 100.00%
# Epoch [18/50], Loss: 0.0001, Accuracy: 100.00%
# Epoch [19/50], Loss: 0.0001, Accuracy: 100.00%
# Epoch [20/50], Loss: 0.0001, Accuracy: 100.00%
# Epoch [21/50], Loss: 0.0002, Accuracy: 100.00%
# Epoch [22/50], Loss: 0.0001, Accuracy: 100.00%
# Epoch [23/50], Loss: 0.0002, Accuracy: 100.00%
# Epoch [24/50], Loss: 0.0001, Accuracy: 100.00%
# Epoch [25/50], Loss: 0.0002, Accuracy: 100.00%
# Epoch [26/50], Loss: 0.0001, Accuracy: 100.00%
# Epoch [27/50], Loss: 0.0000, Accuracy: 100.00%
# Epoch [28/50], Loss: 0.0001, Accuracy: 100.00%
# Epoch [29/50], Loss: 0.0002, Accuracy: 100.00%
# Epoch [30/50], Loss: 0.0002, Accuracy: 100.00%
# Epoch [31/50], Loss: 0.0001, Accuracy: 100.00%
# Epoch [32/50], Loss: 0.0006, Accuracy: 100.00%
# Epoch [33/50], Loss: 0.0002, Accuracy: 100.00%
# Epoch [34/50], Loss: 0.0003, Accuracy: 100.00%
# Epoch [35/50], Loss: 0.0001, Accuracy: 100.00%
# Epoch [36/50], Loss: 0.0002, Accuracy: 100.00%
# Epoch [37/50], Loss: 0.0001, Accuracy: 100.00%
# Epoch [38/50], Loss: 0.0000, Accuracy: 100.00%
# Epoch [39/50], Loss: 0.0002, Accuracy: 100.00%
# Epoch [40/50], Loss: 0.0002, Accuracy: 100.00%
# Epoch [41/50], Loss: 0.0001, Accuracy: 100.00%
# Epoch [42/50], Loss: 0.0001, Accuracy: 100.00%
# Epoch [43/50], Loss: 0.0001, Accuracy: 100.00%
# Epoch [44/50], Loss: 0.0001, Accuracy: 100.00%
# Epoch [45/50], Loss: 0.0002, Accuracy: 100.00%
# Epoch [46/50], Loss: 0.0001, Accuracy: 100.00%
# Epoch [47/50], Loss: 0.0001, Accuracy: 100.00%
# Epoch [48/50], Loss: 0.0001, Accuracy: 100.00%
# Epoch [49/50], Loss: 0.0001, Accuracy: 100.00%
# Epoch [50/50], Loss: 0.0000, Accuracy: 100.00%
# Test Accuracy: 81.71%

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np

# 1. Define transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),   # Resize to fit VGG16 input
    transforms.ToTensor(),
    # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalization for pretrained models
])

# 2. Load datasets (change root as needed)
train_dataset = datasets.ImageFolder(root="/kaggle/input/vision-project-data/Newdata/Train", transform=transform)
test_dataset = datasets.ImageFolder(root="/kaggle/input/vision-project-data/Newdata/Test", transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# 3. Use Pretrained VGG16 model from torchvision
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Load the pretrained VGG16 model
model = models.vgg19(pretrained=True)

# Modify the final fully connected layer for your number of classes (2 classes in your case)
model.classifier[6] = nn.Linear(model.classifier[6].in_features, 2)

# Move model to device
model = model.to(device)

# Optionally, freeze the layers if you want to fine-tune only the final layers
for param in model.parameters():
    param.requires_grad = False

# Unfreeze the final fully connected layer (this is usually the layer we fine-tune)
for param in model.classifier[6].parameters():
    param.requires_grad = True

# 4. Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.classifier[6].parameters(), lr=0.002)

# 5. Training loop
num_epochs = 50
train_losses = []
train_accuracies = []

for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0
    correct = 0
    total = 0

    for batch in train_loader:
        images, labels = batch
        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    avg_loss = epoch_loss / len(train_loader)
    acc = 100 * correct / total
    train_losses.append(avg_loss)
    train_accuracies.append(acc)

    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}, Accuracy: {acc:.2f}%")

# 6. Plot train accuracy and loss
plt.figure(figsize=(12,5))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Train Accuracy', color='green')
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.title("Training Accuracy")
plt.legend()
plt.show()

# 7. Evaluation on test set + confusion matrix
model.eval()
y_true = []
y_pred = []

with torch.no_grad():
    for batch in test_loader:
        images, labels = batch
        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)

        y_true.extend(labels.cpu().numpy())
        y_pred.extend(predicted.cpu().numpy())

# Accuracy
correct = np.sum(np.array(y_true) == np.array(y_pred))
test_acc = 100 * correct / len(y_true)
print(f"Test Accuracy: {test_acc:.2f}%")

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=train_dataset.classes, yticklabels=train_dataset.classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# 100%|██████████| 548M/548M [00:02<00:00,