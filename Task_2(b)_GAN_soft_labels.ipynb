# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.utils as vutils
import matplotlib.pyplot as plt
import numpy as np
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from PIL import Image
import os

# -------------------------
# Generator
# -------------------------
class Generator(nn.Module):
    def __init__(self, nz=100):
        super(Generator, self).__init__()
        self.net = nn.Sequential(
            nn.ConvTranspose2d(nz, 1024, 4, 1, 0, bias=False),
            nn.BatchNorm2d(1024),
            nn.ReLU(True),

            nn.ConvTranspose2d(1024, 512, 4, 2, 1, bias=False),
            nn.BatchNorm2d(512),
            nn.ReLU(True),

            nn.ConvTranspose2d(512, 256, 4, 2, 1, bias=False),
            nn.BatchNorm2d(256),
            nn.ReLU(True),

            nn.ConvTranspose2d(256, 128, 4, 2, 1, bias=False),
            nn.BatchNorm2d(128),
            nn.ReLU(True),

            nn.ConvTranspose2d(128, 64, 4, 2, 1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(True),

            nn.ConvTranspose2d(64, 32, 4, 2, 1, bias=False),
            nn.BatchNorm2d(32),
            nn.ReLU(True),

            nn.ConvTranspose2d(32, 3, 4, 2, 1, bias=False),
            nn.Sigmoid()
        )

    def forward(self, z):
        return self.net(z)

# -------------------------
# Discriminator
# -------------------------
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.net = nn.Sequential(
            nn.Conv2d(3, 32, 4, 2, 1),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(32, 64, 4, 2, 1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(64, 128, 4, 2, 1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(128, 256, 4, 2, 1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(256, 512, 4, 2, 1),
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(512, 1024, 4, 2, 1),
            nn.BatchNorm2d(1024),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(1024, 1, 4, 1, 0),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.net(x).view(-1)

# -------------------------
# Hyperparameters
# -------------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
nz = 100
lr = 0.0002
num_epochs = 500
batch_size = 8

G = Generator(nz).to(device)
D = Discriminator().to(device)

criterion = nn.BCELoss()
optimizerG = optim.Adam(G.parameters(), lr=lr, betas=(0.5, 0.999))
optimizerD = optim.Adam(D.parameters(), lr=lr, betas=(0.5, 0.999))

# -------------------------
# Data Loading
# -------------------------
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(256),
    transforms.ToTensor()
])

train_dataset = datasets.ImageFolder(root="/kaggle/input/vision-project-data/Newdata/Train", transform=transform)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# -------------------------
# Training
# -------------------------
G_losses = []
D_losses = []
fixed_noise = torch.randn(8, nz, 1, 1, device=device)

for epoch in range(num_epochs):
    for i, (real_images, _) in enumerate(train_loader):
        real_images = real_images.to(device)
        batch_size = real_images.size(0)

        # Soft + Noisy Labels
        real_labels = torch.empty(batch_size, device=device).uniform_(0.7, 1.0)
        fake_labels = torch.empty(batch_size, device=device).uniform_(0.0, 0.3)

        # Train Discriminator
        D.zero_grad()
        output_real = D(real_images)
        loss_real = criterion(output_real, real_labels)

        noise = torch.randn(batch_size, nz, 1, 1, device=device)
        fake_images = G(noise)
        output_fake = D(fake_images.detach())
        loss_fake = criterion(output_fake, fake_labels)

        loss_D = loss_real + loss_fake
        loss_D.backward()
        optimizerD.step()

        # Train Generator
        G.zero_grad()
        output = D(fake_images)
        gen_labels  = torch.empty(batch_size, device=device).uniform_(0.7, 1.0)
        loss_G = criterion(output, gen_labels)
        loss_G.backward()
        optimizerG.step()

        G_losses.append(loss_G.item())
        D_losses.append(loss_D.item())

        if i % 50 == 0:
            print(f"Epoch [{epoch+1}/{num_epochs}] Batch {i}/{len(train_loader)} "
                  f"Loss D: {loss_D.item():.4f}, Loss G: {loss_G.item():.4f}")

    # Show generated images after every 20 epochs
    if (epoch + 1) % 20 == 0:
        with torch.no_grad():
            fake_images = G(fixed_noise).detach().cpu()
        grid_fake = vutils.make_grid(fake_images, normalize=True)

        plt.figure(figsize=(6, 6))
        plt.title(f"Fake Images at Epoch {epoch+1}")
        plt.imshow(np.transpose(grid_fake, (1, 2, 0)))
        plt.axis("off")
        plt.show()

# -------------------------
# After training, show 10 generated images
# -------------------------
num_images_to_show = 10
with torch.no_grad():
    for idx in range(num_images_to_show):
        noise = torch.randn(1, nz, 1, 1, device=device)
        fake_image = G(noise).detach().cpu()
        fake_image = fake_image.squeeze(0)
        fake_image = transforms.ToPILImage()(fake_image)

        plt.figure(figsize=(2, 2))
        plt.imshow(fake_image)
        plt.axis("off")
        plt.show()

# -------------------------
# Final Loss Plot
# -------------------------
plt.figure(figsize=(10, 10))
plt.title("Generator and Discriminator Loss During Training")
plt.plot(G_losses, label="G")
plt.plot(D_losses, label="D")
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# Epoch [1/500] Batch 0/11 Loss D: 1.3712, Loss G: 8.8635
# Epoch [2/500] Batch 0/11 Loss D: 2.5040, Loss G: 5.9843
# Epoch [3/500] Batch 0/11 Loss D: 1.4329, Loss G: 3.6520
# Epoch [4/500] Batch 0/11 Loss D: 1.2557, Loss G: 3.3105
# Epoch [5/500] Batch 0/11 Loss D: 0.8258, Loss G: 1.9481
# Epoch [6/500] Batch 0/11 Loss D: 1.3199, Loss G: 2.0668
# Epoch [7/500] Batch 0/11 Loss D: 1.1110, Loss G: 2.4500
# Epoch [8/500] Batch 0/11 Loss D: 0.7427, Loss G: 2.5186
# Epoch [9/500] Batch 0/11 Loss D: 0.8849, Loss G: 2.5719
# Epoch [10/500] Batch 0/11 Loss D: 0.8246, Loss G: 1.9779
# Epoch [11/500] Batch 0/11 Loss D: 0.9299, Loss G: 1.8365
# Epoch [12/500] Batch 0/11 Loss D: 1.0439, Loss G: 1.2983
# Epoch [13/500] Batch 0/11 Loss D: 1.0031, Loss G: 1.7053
# Epoch [14/500] Batch 0/11 Loss D: 1.0296, Loss G: 1.3436
# Epoch [15/500] Batch 0/11 Loss D: 0.9693, Loss G: 1.5557
# Epoch [16/500] Batch 0/11 Loss D: 1.1187, Loss G: 0.9886
# Epoch [17/500] Batch 0/11 Loss D: 1.0558, Loss G: 1.5040
# Epoch [18/500] Batch 0/11 Loss D: 1.3055, Loss G: 2.7446
# Epoch [19/500] Batch 0/11 Loss D: 1.0266, Loss G: 4.1499
# Epoch [20/500] Batch 0/11 Loss D: 0.9438, Loss G: 1.5108
# Epoch [21/500] Batch 0/11 Loss D: 1.4723, Loss G: 4.4934
# Epoch [22/500] Batch 0/11 Loss D: 0.8215, Loss G: 1.7079
# Epoch [23/500] Batch 0/11 Loss D: 0.9530, Loss G: 1.6401
# Epoch [24/500] Batch 0/11 Loss D: 1.1582, Loss G: 1.9301
# Epoch [25/500] Batch 0/11 Loss D: 0.9427, Loss G: 1.0537
# Epoch [26/500] Batch 0/11 Loss D: 1.6241, Loss G: 4.1153
# Epoch [27/500] Batch 0/11 Loss D: 0.8034, Loss G: 1.2611
# Epoch [28/500] Batch 0/11 Loss D: 3.5396, Loss G: 1.9205
# Epoch [29/500] Batch 0/11 Loss D: 1.0506, Loss G: 1.4625
# Epoch [30/500] Batch 0/11 Loss D: 1.0695, Loss G: 1.1571
# Epoch [31/500] Batch 0/11 Loss D: 1.2978, Loss G: 0.9524
# Epoch [32/500] Batch 0/11 Loss D: 1.5921, Loss G: 2.8409
# Epoch [33/500] Batch 0/11 Loss D: 0.7055, Loss G: 1.8884
# Epoch [34/500] Batch 0/11 Loss D: 2.2481, Loss G: 0.9486
# Epoch [35/500] Batch 0/11 Loss D: 1.2417, Loss G: 3.1750
# Epoch [36/500] Batch 0/11 Loss D: 0.9891, Loss G: 2.0184
# Epoch [37/500] Batch 0/11 Loss D: 1.1969, Loss G: 1.4023
# Epoch [38/500] Batch 0/11 Loss D: 1.3576, Loss G: 0.8243
# Epoch [39/500] Batch 0/11 Loss D: 1.7673, Loss G: 3.5525
# Epoch [40/500] Batch 0/11 Loss D: 1.2915, Loss G: 2.1561
# Epoch [41/500] Batch 0/11 Loss D: 1.0122, Loss G: 1.5400
# Epoch [42/500] Batch 0/11 Loss D: 1.0561, Loss G: 1.5838
# Epoch [43/500] Batch 0/11 Loss D: 2.2437, Loss G: 3.6039
# Epoch [44/500] Batch 0/11 Loss D: 0.8090, Loss G: 1.7018
# Epoch [45/500] Batch 0/11 Loss D: 0.9734, Loss G: 2.2333
# Epoch [46/500] Batch 0/11 Loss D: 0.9539, Loss G: 2.0901
# Epoch [47/500] Batch 0/11 Loss D: 1.0791, Loss G: 2.8882
# Epoch [48/500] Batch 0/11 Loss D: 0.8498, Loss G: 2.0157
# Epoch [49/500] Batch 0/11 Loss D: 0.9957, Loss G: 1.9355
# Epoch [50/500] Batch 0/11 Loss D: 2.5769, Loss G: 2.5043
# Epoch [51/500] Batch 0/11 Loss D: 1.1060, Loss G: 1.2316
# Epoch [52/500] Batch 0/11 Loss D: 1.1641, Loss G: 1.2630
# Epoch [53/500] Batch 0/11 Loss D: 2.3800, Loss G: 3.3425
# Epoch [54/500] Batch 0/11 Loss D: 1.0648, Loss G: 1.6774
# Epoch [55/500] Batch 0/11 Loss D: 2.2696, Loss G: 1.7027
# Epoch [56/500] Batch 0/11 Loss D: 1.0602, Loss G: 1.1930
# Epoch [57/500] Batch 0/11 Loss D: 2.1425, Loss G: 5.3051
# Epoch [58/500] Batch 0/11 Loss D: 1.0340, Loss G: 1.8003
# Epoch [59/500] Batch 0/11 Loss D: 1.1347, Loss G: 1.6882
# Epoch [60/500] Batch 0/11 Loss D: 0.9469, Loss G: 1.3506
# Epoch [61/500] Batch 0/11 Loss D: 2.3099, Loss G: 3.2236
# Epoch [62/500] Batch 0/11 Loss D: 0.9984, Loss G: 1.5298
# Epoch [63/500] Batch 0/11 Loss D: 1.2290, Loss G: 2.8993
# Epoch [64/500] Batch 0/11 Loss D: 1.0538, Loss G: 2.3539
# Epoch [65/500] Batch 0/11 Loss D: 1.0821, Loss G: 2.3370
# Epoch [66/500] Batch 0/11 Loss D: 1.2469, Loss G: 1.1274
# Epoch [67/500] Batch 0/11 Loss D: 1.7893, Loss G: 4.3277
# Epoch [68/500] Batch 0/11 Loss D: 0.9548, Loss G: 1.6911
# Epoch [69/500] Batch 0/11 Loss D: 1.0705, Loss G: 1.9345
# Epoch [70/500] Batch 0/11 Loss D: 1.0374, Loss G: 1.7046
# Epoch [71/500] Batch 0/11 Loss D: 0.9705, Loss G: 1.0888
# Epoch [72/500] Batch 0/11 Loss D: 2.0641, Loss G: 2.8606
# Epoch [73/500] Batch 0/11 Loss D: 1.8083, Loss G: 2.9332
# Epoch [74/500] Batch 0/11 Loss D: 1.0511, Loss G: 1.7400
# Epoch [75/500] Batch 0/11 Loss D: 0.9282, Loss G: 1.3921
# Epoch [76/500] Batch 0/11 Loss D: 1.0880, Loss G: 2.1469
# Epoch [77/500] Batch 0/11 Loss D: 3.4034, Loss G: 2.6210
# Epoch [78/500] Batch 0/11 Loss D: 1.1435, Loss G: 1.9749
# Epoch [79/500] Batch 0/11 Loss D: 1.0123, Loss G: 2.2747
# Epoch [80/500] Batch 0/11 Loss D: 1.1483, Loss G: 1.0696
# Epoch [81/500] Batch 0/11 Loss D: 1.0059, Loss G: 1.5746
# Epoch [82/500] Batch 0/11 Loss D: 0.9304, Loss G: 1.8196
# Epoch [83/500] Batch 0/11 Loss D: 1.3204, Loss G: 2.7623
# Epoch [84/500] Batch 0/11 Loss D: 0.9107, Loss G: 2.5094
# Epoch [85/500] Batch 0/11 Loss D: 0.8708, Loss G: 2.3376
# Epoch [86/500] Batch 0/11 Loss D: 1.0354, Loss G: 2.1167
# Epoch [87/500] Batch 0/11 Loss D: 1.4952, Loss G: 4.3343
# Epoch [88/500] Batch 0/11 Loss D: 0.9128, Loss G: 2.0489
# Epoch [89/500] Batch 0/11 Loss D: 1.2497, Loss G: 3.5545
# Epoch [90/500] Batch 0/11 Loss D: 1.1348, Loss G: 1.7126
# Epoch [91/500] Batch 0/11 Loss D: 1.3721, Loss G: 2.6016
# Epoch [92/500] Batch 0/11 Loss D: 1.4094, Loss G: 3.5183
# Epoch [93/500] Batch 0/11 Loss D: 1.1828, Loss G: 2.1389
# Epoch [94/500] Batch 0/11 Loss D: 0.8784, Loss G: 1.0463
# Epoch [95/500] Batch 0/11 Loss D: 0.9439, Loss G: 1.7247
# Epoch [96/500] Batch 0/11 Loss D: 0.9987, Loss G: 2.1482
# Epoch [97/500] Batch 0/11 Loss D: 0.7905, Loss G: 2.0548
# Epoch [98/500] Batch 0/11 Loss D: 0.8817, Loss G: 1.7585
# Epoch [99/500] Batch 0/11 Loss D: 1.3059, Loss G: 3.1314
# Epoch [100/500] Batch 0/11 Loss D: 1.0196, Loss G: 2.3620
# Epoch [101/500] Batch 0/11 Loss D: 1.6318, Loss G: 3.7735
# Epoch [102/500] Batch 0/11 Loss D: 0.9580, Loss G: 1.6517
# Epoch [103/500] Batch 0/11 Loss D: 0.8770, Loss G: 1.9710
# Epoch [104/500] Batch 0/11 Loss D: 1.3647, Loss G: 3.8778
# Epoch [105/500] Batch 0/11 Loss D: 1.5778, Loss G: 2.7662
# Epoch [106/500] Batch 0/11 Loss D: 1.0383, Loss G: 2.5621
# Epoch [107/500] Batch 0/11 Loss D: 1.3209, Loss G: 2.8764
# Epoch [108/500] Batch 0/11 Loss D: 1.3917, Loss G: 3.0695
# Epoch [109/500] Batch 0/11 Loss D: 0.8072, Loss G: 1.9234
# Epoch [110/500] Batch 0/11 Loss D: 0.8859, Loss G: 1.3194
# Epoch [111/500] Batch 0/11 Loss D: 0.8154, Loss G: 1.7116
# Epoch [112/500] Batch 0/11 Loss D: 1.0175, Loss G: 2.3281
# Epoch [113/500] Batch 0/11 Loss D: 1.4096, Loss G: 2.6392
# Epoch [114/500] Batch 0/11 Loss D: 0.8586, Loss G: 2.6182
# Epoch [115/500] Batch 0/11 Loss D: 0.8911, Loss G: 2.3930
# Epoch [116/500] Batch 0/11 Loss D: 1.2198, Loss G: 3.2051
# Epoch [117/500] Batch 0/11 Loss D: 0.9063, Loss G: 2.5228
# Epoch [118/500] Batch 0/11 Loss D: 0.9789, Loss G: 2.0852
# Epoch [119/500] Batch 0/11 Loss D: 0.9674, Loss G: 2.5361
# Epoch [120/500] Batch 0/11 Loss D: 0.9649, Loss G: 1.2162
# Epoch [121/500] Batch 0/11 Loss D: 1.0994, Loss G: 1.6867
# Epoch [122/500] Batch 0/11 Loss D: 1.0850, Loss G: 2.1663
# Epoch [123/500] Batch 0/11 Loss D: 0.9232, Loss G: 1.2582
# Epoch [124/500] Batch 0/11 Loss D: 0.8188, Loss G: 1.5865
# Epoch [125/500] Batch 0/11 Loss D: 0.9119, Loss G: 1.4172
# Epoch [126/500] Batch 0/11 Loss D: 1.0233, Loss G: 1.6479
# Epoch [127/500] Batch 0/11 Loss D: 1.0621, Loss G: 2.0763
# Epoch [128/500] Batch 0/11 Loss D: 1.0532, Loss G: 1.0159
# Epoch [129/500] Batch 0/11 Loss D: 1.0390, Loss G: 2.1644
# Epoch [130/500] Batch 0/11 Loss D: 1.0446, Loss G: 1.4932
# Epoch [131/500] Batch 0/11 Loss D: 1.4225, Loss G: 2.9359
# Epoch [132/500] Batch 0/11 Loss D: 0.8526, Loss G: 1.8269
# Epoch [133/500] Batch 0/11 Loss D: 1.0442, Loss G: 1.9049
# Epoch [134/500] Batch 0/11 Loss D: 0.9268, Loss G: 1.4171
# Epoch [135/500] Batch 0/11 Loss D: 0.9281, Loss G: 1.9995
# Epoch [136/500] Batch 0/11 Loss D: 1.0668, Loss G: 2.2737
# Epoch [137/500] Batch 0/11 Loss D: 1.0180, Loss G: 2.2003
# Epoch [138/500] Batch 0/11 Loss D: 0.9836, Loss G: 1.7882
# Epoch [139/500] Batch 0/11 Loss D: 0.9443, Loss G: 1.9201
# Epoch [140/500] Batch 0/11 Loss D: 0.9518, Loss G: 1.1338
# Epoch [141/500] Batch 0/11 Loss D: 1.2512, Loss G: 2.1079
# Epoch [142/500] Batch 0/11 Loss D: 0.8406, Loss G: 1.7602
# Epoch [143/500] Batch 0/11 Loss D: 0.9909, Loss G: 2.3839
# Epoch [144/500] Batch 0/11 Loss D: 1.2736, Loss G: 3.0146
# Epoch [145/500] Batch 0/11 Loss D: 1.6990, Loss G: 3.8097
# Epoch [146/500] Batch 0/11 Loss D: 1.1342, Loss G: 2.0257
# Epoch [147/500] Batch 0/11 Loss D: 0.9659, Loss G: 1.6283
# Epoch [148/500] Batch 0/11 Loss D: 1.1249, Loss G: 2.5612
# Epoch [149/500] Batch 0/11 Loss D: 1.2708, Loss G: 1.4498
# Epoch [150/500] Batch 0/11 Loss D: 0.9582, Loss G: 1.8943
# Epoch [151/500] Batch 0/11 Loss D: 0.8468, Loss G: 1.8598
# Epoch [152/500] Batch 0/11 Loss D: 1.0845, Loss G: 2.0734
# Epoch [153/500] Batch 0/11 Loss D: 0.7278, Loss G: 2.2639
# Epoch [154/500] Batch 0/11 Loss D: 0.9576, Loss G: 1.7617
# Epoch [155/500] Batch 0/11 Loss D: 1.1428, Loss G: 1.6466
# Epoch [156/500] Batch 0/11 Loss D: 0.9633, Loss G: 1.5495
# Epoch [157/500] Batch 0/11 Loss D: 1.1830, Loss G: 1.3385
# Epoch [158/500] Batch 0/11 Loss D: 1.0458, Loss G: 1.6389
# Epoch [159/500] Batch 0/11 Loss D: 1.2415, Loss G: 4.0122
# Epoch [160/500] Batch 0/11 Loss D: 1.1085, Loss G: 2.4497
# Epoch [161/500] Batch 0/11 Loss D: 0.7896, Loss G: 1.6427
# Epoch [162/500] Batch 0/11 Loss D: 1.0736, Loss G: 1.7516
# Epoch [163/500] Batch 0/11 Loss D: 1.2142, Loss G: 3.2413
# Epoch [164/500] Batch 0/11 Loss D: 2.6530, Loss G: 1.9453
# Epoch [165/500] Batch 0/11 Loss D: 0.9571, Loss G: 2.0001
# Epoch [166/500] Batch 0/11 Loss D: 1.0539, Loss G: 1.2523
# Epoch [167/500] Batch 0/11 Loss D: 2.4754, Loss G: 3.3941
# Epoch [168/500] Batch 0/11 Loss D: 0.9876, Loss G: 2.2311
# Epoch [169/500] Batch 0/11 Loss D: 0.9497, Loss G: 2.0987
# Epoch [170/500] Batch 0/11 Loss D: 1.1119, Loss G: 1.5335
# Epoch [171/500] Batch 0/11 Loss D: 0.9267, Loss G: 2.0099
# Epoch [172/500] Batch 0/11 Loss D: 1.2940, Loss G: 5.2848
# Epoch [173/500] Batch 0/11 Loss D: 0.8932, Loss G: 1.7592
# Epoch [174/500] Batch 0/11 Loss D: 1.4967, Loss G: 2.1262
# Epoch [175/500] Batch 0/11 Loss D: 0.9702, Loss G: 1.5762
# Epoch [176/500] Batch 0/11 Loss D: 0.8666, Loss G: 2.0224
# Epoch [177/500] Batch 0/11 Loss D: 1.0705, Loss G: 2.0429
# Epoch [178/500] Batch 0/11 Loss D: 0.8986, Loss G: 1.4011
# Epoch [179/500] Batch 0/11 Loss D: 1.2881, Loss G: 3.0670
# Epoch [180/500] Batch 0/11 Loss D: 0.9440, Loss G: 1.6065
# Epoch [181/500] Batch 0/11 Loss D: 1.0633, Loss G: 2.3170
# Epoch [182/500] Batch 0/11 Loss D: 0.9773, Loss G: 1.9788
# Epoch [183/500] Batch 0/11 Loss D: 1.0542, Loss G: 1.6792
# Epoch [184/500] Batch 0/11 Loss D: 0.9844, Loss G: 2.0837
# Epoch [185/500] Batch 0/11 Loss D: 0.9774, Loss G: 1.7046
# Epoch [186/500] Batch 0/11 Loss D: 0.9790, Loss G: 1.4740
# Epoch [187/500] Batch 0/11 Loss D: 0.9110, Loss G: 1.7721
# Epoch [188/500] Batch 0/11 Loss D: 0.9446, Loss G: 2.0421
# Epoch [189/500] Batch 0/11 Loss D: 0.9482, Loss G: 1.2916
# Epoch [190/500] Batch 0/11 Loss D: 1.2514, Loss G: 3.2763
# Epoch [191/500] Batch 0/11 Loss D: 0.9952, Loss G: 2.4226
# Epoch [192/500] Batch 0/11 Loss D: 0.8473, Loss G: 1.9167
# Epoch [193/500] Batch 0/11 Loss D: 0.8790, Loss G: 1.5483
# Epoch [194/500] Batch 0/11 Loss D: 0.8055, Loss G: 1.8153
# Epoch [195/500] Batch 0/11 Loss D: 1.0228, Loss G: 2.2464
# Epoch [196/500] Batch 0/11 Loss D: 0.8705, Loss G: 1.7671
# Epoch [197/500] Batch 0/11 Loss D: 0.9479, Loss G: 2.0217
# Epoch [198/500] Batch 0/11 Loss D: 0.9188, Loss G: 2.0811
# Epoch [199/500] Batch 0/11 Loss D: 1.5681, Loss G: 0.9928
# Epoch [200/500] Batch 0/11 Loss D: 1.2502, Loss G: 2.6370
# Epoch [201/500] Batch 0/11 Loss D: 0.9072, Loss G: 2.5877
# Epoch [202/500] Batch 0/11 Loss D: 0.9331, Loss G: 1.4190
# Epoch [203/500] Batch 0/11 Loss D: 0.9260, Loss G: 1.7780
# Epoch [204/500] Batch 0/11 Loss D: 1.0109, Loss G: 1.5522
# Epoch [205/500] Batch 0/11 Loss D: 0.8316, Loss G: 2.3054
# Epoch [206/500] Batch 0/11 Loss D: 0.8591, Loss G: 1.6461
# Epoch [207/500] Batch 0/11 Loss D: 1.1660, Loss G: 3.0896
# Epoch [208/500] Batch 0/11 Loss D: 1.6679, Loss G: 3.0059
# Epoch [209/500] Batch 0/11 Loss D: 0.7869, Loss G: 2.0614
# Epoch [210/500] Batch 0/11 Loss D: 1.2303, Loss G: 2.7549
# Epoch [211/500] Batch 0/11 Loss D: 0.8521, Loss G: 1.5937
# Epoch [212/500] Batch 0/11 Loss D: 0.8278, Loss G: 2.2607
# Epoch [213/500] Batch 0/11 Loss D: 1.2017, Loss G: 2.7667
# Epoch [214/500] Batch 0/11 Loss D: 2.0728, Loss G: 3.0364
# Epoch [215/500] Batch 0/11 Loss D: 0.9146, Loss G: 1.9765
# Epoch [216/500] Batch 0/11 Loss D: 0.8584, Loss G: 1.6288
# Epoch [217/500] Batch 0/11 Loss D: 1.2625, Loss G: 1.8519
# Epoch [218/500] Batch 0/11 Loss D: 0.8875, Loss G: 1.7962
# Epoch [219/500] Batch 0/11 Loss D: 1.2156, Loss G: 3.7578
# Epoch [220/500] Batch 0/11 Loss D: 0.9651, Loss G: 2.5710
# Epoch [221/500] Batch 0/11 Loss D: 0.9641, Loss G: 1.5450
# Epoch [222/500] Batch 0/11 Loss D: 0.8884, Loss G: 2.0750
# Epoch [223/500] Batch 0/11 Loss D: 0.8492, Loss G: 1.7894
# Epoch [224/500] Batch 0/11 Loss D: 1.1644, Loss G: 2.6821
# Epoch [225/500] Batch 0/11 Loss D: 0.9135, Loss G: 1.5075
# Epoch [226/500] Batch 0/11 Loss D: 1.4628, Loss G: 2.2575
# Epoch [227/500] Batch 0/11 Loss D: 0.9701, Loss G: 1.5250
# Epoch [228/500] Batch 0/11 Loss D: 0.9537, Loss G: 1.2321
# Epoch [229/500] Batch 0/11 Loss D: 0.7346, Loss G: 2.0309
# Epoch [230/500] Batch 0/11 Loss D: 0.8692, Loss G: 2.0359
# Epoch [231/500] Batch 0/11 Loss D: 0.9300, Loss G: 1.7920
# Epoch [232/500] Batch 0/11 Loss D: 1.0112, Loss G: 2.3411
# Epoch [233/500] Batch 0/11 Loss D: 0.9183, Loss G: 1.5569
# Epoch [234/500] Batch 0/11 Loss D: 0.9425, Loss G: 1.3406
# Epoch [235/500] Batch 0/11 Loss D: 0.9857, Loss G: 1.6763
# Epoch [236/500] Batch 0/11 Loss D: 0.8221, Loss G: 1.8284
# Epoch [237/500] Batch 0/11 Loss D: 1.7505, Loss G: 2.4457
# Epoch [238/500] Batch 0/11 Loss D: 1.0384, Loss G: 1.1895
# Epoch [239/500] Batch 0/11 Loss D: 0.9625, Loss G: 1.7197
# Epoch [240/500] Batch 0/11 Loss D: 1.0327, Loss G: 1.7144
# Epoch [241/500] Batch 0/11 Loss D: 0.8287, Loss G: 2.1279
# Epoch [242/500] Batch 0/11 Loss D: 0.8124, Loss G: 1.3650
# Epoch [243/500] Batch 0/11 Loss D: 1.4753, Loss G: 1.2538
# Epoch [244/500] Batch 0/11 Loss D: 1.0074, Loss G: 1.8593
# Epoch [245/500] Batch 0/11 Loss D: 1.1539, Loss G: 2.7484
# Epoch [246/500] Batch 0/11 Loss D: 0.9770, Loss G: 1.5150
# Epoch [247/500] Batch 0/11 Loss D: 1.0151, Loss G: 1.8369
# Epoch [248/500] Batch 0/11 Loss D: 0.9563, Loss G: 1.9721
# Epoch [249/500] Batch 0/11 Loss D: 0.9463, Loss G: 1.8652
# Epoch [250/500] Batch 0/11 Loss D: 1.0223, Loss G: 1.9250
# Epoch [251/500] Batch 0/11 Loss D: 0.9014, Loss G: 1.9553
# Epoch [252/500] Batch 0/11 Loss D: 1.1998, Loss G: 2.4762
# Epoch [253/500] Batch 0/11 Loss D: 0.9214, Loss G: 2.3888
# Epoch [254/500] Batch 0/11 Loss D: 0.8563, Loss G: 1.9565
# Epoch [255/500] Batch 0/11 Loss D: 0.8101, Loss G: 1.7990
# Epoch [256/500] Batch 0/11 Loss D: 0.8764, Loss G: 1.5137
# Epoch [257/500] Batch 0/11 Loss D: 1.0722, Loss G: 2.5923
# Epoch [258/500] Batch 0/11 Loss D: 0.8232, Loss G: 1.6742
# Epoch [259/500] Batch 0/11 Loss D: 1.0228, Loss G: 1.4192
# Epoch [260/500] Batch 0/11 Loss D: 1.0423, Loss G: 1.2794
# Epoch [261/500] Batch 0/11 Loss D: 1.2971, Loss G: 1.2709
# Epoch [262/500] Batch 0/11 Loss D: 0.9545, Loss G: 2.1932
# Epoch [263/500] Batch 0/11 Loss D: 0.8785, Loss G: 1.5801
# Epoch [264/500] Batch 0/11 Loss D: 0.9303, Loss G: 1.6889
# Epoch [265/500] Batch 0/11 Loss D: 1.2341, Loss G: 2.3327
# Epoch [266/500] Batch 0/11 Loss D: 0.7385, Loss G: 2.0031
# Epoch [267/500] Batch 0/11 Loss D: 1.1584, Loss G: 2.9035
# Epoch [268/500] Batch 0/11 Loss D: 1.4427, Loss G: 2.4626
# Epoch [269/500] Batch 0/11 Loss D: 0.9129, Loss G: 1.4456
# Epoch [270/500] Batch 0/11 Loss D: 0.7701, Loss G: 1.6474
# Epoch [271/500] Batch 0/11 Loss D: 0.9949, Loss G: 1.0369
# Epoch [272/500] Batch 0/11 Loss D: 0.9375, Loss G: 1.5823
# Epoch [273/500] Batch 0/11 Loss D: 1.7838, Loss G: 3.3160
# Epoch [274/500] Batch 0/11 Loss D: 0.7689, Loss G: 1.8527
# Epoch [275/500] Batch 0/11 Loss D: 0.8922, Loss G: 2.0752
# Epoch [276/500] Batch 0/11 Loss D: 0.9371, Loss G: 1.3852
# Epoch [277/500] Batch 0/11 Loss D: 1.0566, Loss G: 2.0445
# Epoch [278/500] Batch 0/11 Loss D: 1.0016, Loss G: 2.0594
# Epoch [279/500] Batch 0/11 Loss D: 0.8657, Loss G: 1.5303
# Epoch [280/500] Batch 0/11 Loss D: 0.7611, Loss G: 1.8801
# Epoch [281/500] Batch 0/11 Loss D: 0.8004, Loss G: 1.6456
# Epoch [282/500] Batch 0/11 Loss D: 1.0044, Loss G: 1.9735
# Epoch [283/500] Batch 0/11 Loss D: 0.8611, Loss G: 1.7739
# Epoch [284/500] Batch 0/11 Loss D: 0.8519, Loss G: 1.7889
# Epoch [285/500] Batch 0/11 Loss D: 1.2413, Loss G: 2.5546
# Epoch [286/500] Batch 0/11 Loss D: 0.8193, Loss G: 1.7914
# Epoch [287/500] Batch 0/11 Loss D: 1.3749, Loss G: 2.7416
# Epoch [288/500] Batch 0/11 Loss D: 0.7300, Loss G: 1.5486
# Epoch [289/500] Batch 0/11 Loss D: 0.9431, Loss G: 1.9731
# Epoch [290/500] Batch 0/11 Loss D: 0.6053, Loss G: 2.2522
# Epoch [291/500] Batch 0/11 Loss D: 0.9813, Loss G: 1.6968
# Epoch [292/500] Batch 0/11 Loss D: 0.9564, Loss G: 1.5658
# Epoch [293/500] Batch 0/11 Loss D: 0.8419, Loss G: 2.3109
# Epoch [294/500] Batch 0/11 Loss D: 0.8882, Loss G: 1.8727
# Epoch [295/500] Batch 0/11 Loss D: 0.9278, Loss G: 2.2185
# Epoch [296/500] Batch 0/11 Loss D: 0.9100, Loss G: 1.2777
# Epoch [297/500] Batch 0/11 Loss D: 0.8567, Loss G: 1.7362
# Epoch [298/500] Batch 0/11 Loss D: 1.1408, Loss G: 2.1259
# Epoch [299/500] Batch 0/11 Loss D: 1.0407, Loss G: 1.5844
# Epoch [300/500] Batch 0/11 Loss D: 0.8916, Loss G: 2.2299
# Epoch [301/500] Batch 0/11 Loss D: 0.9036, Loss G: 2.0358
# Epoch [302/500] Batch 0/11 Loss D: 1.1627, Loss G: 1.6459
# Epoch [303/500] Batch 0/11 Loss D: 0.7400, Loss G: 1.8980
# Epoch [304/500] Batch 0/11 Loss D: 0.9562, Loss G: 2.4307
# Epoch [305/500] Batch 0/11 Loss D: 0.9276, Loss G: 1.6422
# Epoch [306/500] Batch 0/11 Loss D: 1.4051, Loss G: 1.6084
# Epoch [307/500] Batch 0/11 Loss D: 0.7637, Loss G: 1.8151
# Epoch [308/500] Batch 0/11 Loss D: 1.5728, Loss G: 1.6648
# Epoch [309/500] Batch 0/11 Loss D: 1.0077, Loss G: 2.1160
# Epoch [310/500] Batch 0/11 Loss D: 1.0271, Loss G: 1.5812
# Epoch [311/500] Batch 0/11 Loss D: 1.1069, Loss G: 1.8890
# Epoch [312/500] Batch 0/11 Loss D: 0.9899, Loss G: 1.8066
# Epoch [313/500] Batch 0/11 Loss D: 0.9563, Loss G: 1.6358
# Epoch [314/500] Batch 0/11 Loss D: 1.0837, Loss G: 2.0692
# Epoch [315/500] Batch 0/11 Loss D: 1.1383, Loss G: 1.8967
# Epoch [316/500] Batch 0/11 Loss D: 1.1615, Loss G: 2.0921
# Epoch [317/500] Batch 0/11 Loss D: 0.9106, Loss G: 1.9983
# Epoch [318/500] Batch 0/11 Loss D: 0.8623, Loss G: 1.6901
# Epoch [319/500] Batch 0/11 Loss D: 0.9204, Loss G: 1.6447
# Epoch [320/500] Batch 0/11 Loss D: 0.9947, Loss G: 2.3544
# Epoch [321/500] Batch 0/11 Loss D: 1.1059, Loss G: 1.8355
# Epoch [322/500] Batch 0/11 Loss D: 1.0595, Loss G: 1.9155
# Epoch [323/500] Batch 0/11 Loss D: 0.9370, Loss G: 1.8521
# Epoch [324/500] Batch 0/11 Loss D: 0.8873, Loss G: 1.7124
# Epoch [325/500] Batch 0/11 Loss D: 0.9977, Loss G: 1.7993
# Epoch [326/500] Batch 0/11 Loss D: 0.8545, Loss G: 1.7050
# Epoch [327/500] Batch 0/11 Loss D: 0.8048, Loss G: 1.4981
# Epoch [328/500] Batch 0/11 Loss D: 1.2444, Loss G: 2.2546
# Epoch [329/500] Batch 0/11 Loss D: 0.8822, Loss G: 1.8990
# Epoch [330/500] Batch 0/11 Loss D: 1.1260, Loss G: 1.1851
# Epoch [331/500] Batch 0/11 Loss D: 0.8247, Loss G: 2.2935
# Epoch [332/500] Batch 0/11 Loss D: 0.9638, Loss G: 1.5039
# Epoch [333/500] Batch 0/11 Loss D: 0.9029, Loss G: 1.7376
# Epoch [334/500] Batch 0/11 Loss D: 0.8350, Loss G: 1.3504
# Epoch [335/500] Batch 0/11 Loss D: 1.2537, Loss G: 2.0839
# Epoch [336/500] Batch 0/11 Loss D: 0.8993, Loss G: 1.6074
# Epoch [337/500] Batch 0/11 Loss D: 0.8735, Loss G: 2.0689
# Epoch [338/500] Batch 0/11 Loss D: 1.2596, Loss G: 2.6191
# Epoch [339/500] Batch 0/11 Loss D: 0.9137, Loss G: 1.5176
# Epoch [340/500] Batch 0/11 Loss D: 0.9356, Loss G: 1.1784
# Epoch [341/500] Batch 0/11 Loss D: 0.9777, Loss G: 1.4561
# Epoch [342/500] Batch 0/11 Loss D: 1.0226, Loss G: 2.0211
# Epoch [343/500] Batch 0/11 Loss D: 0.9137, Loss G: 2.1337
# Epoch [344/500] Batch 0/11 Loss D: 0.9740, Loss G: 1.9542
# Epoch [345/500] Batch 0/11 Loss D: 0.9129, Loss G: 2.0074
# Epoch [346/500] Batch 0/11 Loss D: 0.8590, Loss G: 1.6223
# Epoch [347/500] Batch 0/11 Loss D: 1.0255, Loss G: 1.9100
# Epoch [348/500] Batch 0/11 Loss D: 1.6084, Loss G: 2.6758
# Epoch [349/500] Batch 0/11 Loss D: 1.3455, Loss G: 2.1845
# Epoch [350/500] Batch 0/11 Loss D: 1.0591, Loss G: 1.4719
# Epoch [351/500] Batch 0/11 Loss D: 0.9625, Loss G: 2.2270
# Epoch [352/500] Batch 0/11 Loss D: 1.0979, Loss G: 1.4758
# Epoch [353/500] Batch 0/11 Loss D: 1.0007, Loss G: 1.9846
# Epoch [354/500] Batch 0/11 Loss D: 0.9237, Loss G: 1.4079
# Epoch [355/500] Batch 0/11 Loss D: 0.9569, Loss G: 1.8798
# Epoch [356/500] Batch 0/11 Loss D: 0.9711, Loss G: 1.4162
# Epoch [357/500] Batch 0/11 Loss D: 0.9083, Loss G: 2.1638
# Epoch [358/500] Batch 0/11 Loss D: 0.9927, Loss G: 1.5192
# Epoch [359/500] Batch 0/11 Loss D: 1.0277, Loss G: 1.1333
# Epoch [360/500] Batch 0/11 Loss D: 0.9508, Loss G: 1.6788
# Epoch [361/500] Batch 0/11 Loss D: 1.0760, Loss G: 2.1132
# Epoch [362/500] Batch 0/11 Loss D: 0.8057, Loss G: 2.2168
# Epoch [363/500] Batch 0/11 Loss D: 0.7734, Loss G: 1.6169
# Epoch [364/500] Batch 0/11 Loss D: 0.8742, Loss G: 1.7881
# Epoch [365/500] Batch 0/11 Loss D: 1.1705, Loss G: 1.4597
# Epoch [366/500] Batch 0/11 Loss D: 1.0123, Loss G: 1.8035
# Epoch [367/500] Batch 0/11 Loss D: 1.0470, Loss G: 1.6107
# Epoch [368/500] Batch 0/11 Loss D: 0.8518, Loss G: 1.6888
# Epoch [369/500] Batch 0/11 Loss D: 0.8042, Loss G: 1.7201
# Epoch [370/500] Batch 0/11 Loss D: 0.9650, Loss G: 1.7530
# Epoch [371/500] Batch 0/11 Loss D: 0.8032, Loss G: 1.7224
# Epoch [372/500] Batch 0/11 Loss D: 0.8875, Loss G: 1.7709
# Epoch [373/500] Batch 0/11 Loss D: 0.8196, Loss G: 1.8983
# Epoch [374/500] Batch 0/11 Loss D: 1.2446, Loss G: 1.9601
# Epoch [375/500] Batch 0/11 Loss D: 0.9640, Loss G: 2.0732
# Epoch [376/500] Batch 0/11 Loss D: 0.9974, Loss G: 1.5636
# Epoch [377/500] Batch 0/11 Loss D: 0.9697, Loss G: 2.3833
# Epoch [378/500] Batch 0/11 Loss D: 0.9404, Loss G: 2.1788
# Epoch [379/500] Batch 0/11 Loss D: 1.2606, Loss G: 2.9038
# Epoch [380/500] Batch 0/11 Loss D: 1.0292, Loss G: 2.4618
# Epoch [381/500] Batch 0/11 Loss D: 1.3967, Loss G: 2.7215
# Epoch [382/500] Batch 0/11 Loss D: 0.9364, Loss G: 2.1189
# Epoch [383/500] Batch 0/11 Loss D: 0.8850, Loss G: 2.0833
# Epoch [384/500] Batch 0/11 Loss D: 0.8921, Loss G: 1.5435
# Epoch [385/500] Batch 0/11 Loss D: 0.8291, Loss G: 2.0297
# Epoch [386/500] Batch 0/11 Loss D: 0.9219, Loss G: 1.7790
# Epoch [387/500] Batch 0/11 Loss D: 0.9370, Loss G: 1.8306
# Epoch [388/500] Batch 0/11 Loss D: 1.0380, Loss G: 2.4177
# Epoch [389/500] Batch 0/11 Loss D: 1.1366, Loss G: 1.8389
# Epoch [390/500] Batch 0/11 Loss D: 0.7928, Loss G: 1.8820
# Epoch [391/500] Batch 0/11 Loss D: 0.8915, Loss G: 1.7164
# Epoch [392/500] Batch 0/11 Loss D: 0.8611, Loss G: 1.7048
# Epoch [393/500] Batch 0/11 Loss D: 1.2860, Loss G: 2.4257
# Epoch [394/500] Batch 0/11 Loss D: 0.9395, Loss G: 1.9729
# Epoch [395/500] Batch 0/11 Loss D: 0.8475, Loss G: 2.0343
# Epoch [396/500] Batch 0/11 Loss D: 0.9133, Loss G: 1.6760
# Epoch [397/500] Batch 0/11 Loss D: 0.8893, Loss G: 1.9339
# Epoch [398/500] Batch 0/11 Loss D: 0.9034, Loss G: 2.8060
# Epoch [399/500] Batch 0/11 Loss D: 0.9458, Loss G: 1.7353
# Epoch [400/500] Batch 0/11 Loss D: 1.0361, Loss G: 2.1217
# Epoch [401/500] Batch 0/11 Loss D: 1.0312, Loss G: 2.1461
# Epoch [402/500] Batch 0/11 Loss D: 1.0667, Loss G: 1.1779
# Epoch [403/500] Batch 0/11 Loss D: 0.8873, Loss G: 1.3828
# Epoch [404/500] Batch 0/11 Loss D: 1.0174, Loss G: 2.0793
# Epoch [405/500] Batch 0/11 Loss D: 0.9878, Loss G: 1.8278
# Epoch [406/500] Batch 0/11 Loss D: 0.9314, Loss G: 2.0339
# Epoch [407/500] Batch 0/11 Loss D: 0.9285, Loss G: 1.8778
# Epoch [408/500] Batch 0/11 Loss D: 0.8034, Loss G: 2.2235
# Epoch [409/500] Batch 0/11 Loss D: 1.0773, Loss G: 2.2760
# Epoch [410/500] Batch 0/11 Loss D: 0.9273, Loss G: 1.6775
# Epoch [411/500] Batch 0/11 Loss D: 0.7874, Loss G: 2.0041
# Epoch [412/500] Batch 0/11 Loss D: 0.8709, Loss G: 1.6842
# Epoch [413/500] Batch 0/11 Loss D: 0.8769, Loss G: 1.4301
# Epoch [414/500] Batch 0/11 Loss D: 0.9222, Loss G: 1.9748
# Epoch [415/500] Batch 0/11 Loss D: 0.8222, Loss G: 1.8148
# Epoch [416/500] Batch 0/11 Loss D: 0.8334, Loss G: 1.6809
# Epoch [417/500] Batch 0/11 Loss D: 0.9248, Loss G: 1.3973
# Epoch [418/500] Batch 0/11 Loss D: 1.0987, Loss G: 1.8876
# Epoch [419/500] Batch 0/11 Loss D: 1.1177, Loss G: 2.2706
# Epoch [420/500] Batch 0/11 Loss D: 1.0141, Loss G: 1.6154
# Epoch [421/500] Batch 0/11 Loss D: 1.0115, Loss G: 1.1154
# Epoch [422/500] Batch 0/11 Loss D: 1.2888, Loss G: 2.7003
# Epoch [423/500] Batch 0/11 Loss D: 0.9125, Loss G: 1.8911
# Epoch [424/500] Batch 0/11 Loss D: 0.7844, Loss G: 1.7652
# Epoch [425/500] Batch 0/11 Loss D: 0.8035, Loss G: 2.0046
# Epoch [426/500] Batch 0/11 Loss D: 0.9695, Loss G: 1.6881
# Epoch [427/500] Batch 0/11 Loss D: 0.8627, Loss G: 1.3692
# Epoch [428/500] Batch 0/11 Loss D: 0.8762, Loss G: 1.1490
# Epoch [429/500] Batch 0/11 Loss D: 0.7727, Loss G: 1.9987
# Epoch [430/500] Batch 0/11 Loss D: 0.8685, Loss G: 2.2467
# Epoch [431/500] Batch 0/11 Loss D: 0.8390, Loss G: 1.6325
# Epoch [432/500] Batch 0/11 Loss D: 0.8919, Loss G: 1.7307
# Epoch [433/500] Batch 0/11 Loss D: 0.9524, Loss G: 1.5966
# Epoch [434/500] Batch 0/11 Loss D: 0.8700, Loss G: 1.5877
# Epoch [435/500] Batch 0/11 Loss D: 0.9738, Loss G: 1.8907
# Epoch [436/500] Batch 0/11 Loss D: 0.7005, Loss G: 1.8947
# Epoch [437/500] Batch 0/11 Loss D: 0.8534, Loss G: 2.1644
# Epoch [438/500] Batch 0/11 Loss D: 1.0207, Loss G: 1.7887
# Epoch [439/500] Batch 0/11 Loss D: 1.1104, Loss G: 2.6107
# Epoch [440/500] Batch 0/11 Loss D: 1.0510, Loss G: 1.5082
# Epoch [441/500] Batch 0/11 Loss D: 0.8938, Loss G: 1.6548
# Epoch [442/500] Batch 0/11 Loss D: 1.3724, Loss G: 2.7392
# Epoch [443/500] Batch 0/11 Loss D: 0.9070, Loss G: 1.7682
# Epoch [444/500] Batch 0/11 Loss D: 1.0237, Loss G: 2.6039
# Epoch [445/500] Batch 0/11 Loss D: 0.9040, Loss G: 1.9074
# Epoch [446/500] Batch 0/11 Loss D: 1.0203, Loss G: 2.6358
# Epoch [447/500] Batch 0/11 Loss D: 1.3455, Loss G: 2.5005
# Epoch [448/500] Batch 0/11 Loss D: 0.9676, Loss G: 1.8084
# Epoch [449/500] Batch 0/11 Loss D: 0.8176, Loss G: 1.6171
# Epoch [450/500] Batch 0/11 Loss D: 1.1201, Loss G: 1.9274
# Epoch [451/500] Batch 0/11 Loss D: 1.6197, Loss G: 3.2674
# Epoch [452/500] Batch 0/11 Loss D: 0.8218, Loss G: 1.9208
# Epoch [453/500] Batch 0/11 Loss D: 0.8625, Loss G: 1.6351
# Epoch [454/500] Batch 0/11 Loss D: 0.7898, Loss G: 1.8032
# Epoch [455/500] Batch 0/11 Loss D: 0.8210, Loss G: 1.1813
# Epoch [456/500] Batch 0/11 Loss D: 0.7856, Loss G: 1.5979
# Epoch [457/500] Batch 0/11 Loss D: 1.0590, Loss G: 2.0186
# Epoch [458/500] Batch 0/11 Loss D: 1.1083, Loss G: 1.7288
# Epoch [459/500] Batch 0/11 Loss D: 0.9572, Loss G: 2.4071
# Epoch [460/500] Batch 0/11 Loss D: 0.8765, Loss G: 1.3942
# Epoch [461/500] Batch 0/11 Loss D: 1.1135, Loss G: 2.4140
# Epoch [462/500] Batch 0/11 Loss D: 0.9285, Loss G: 1.6657
# Epoch [463/500] Batch 0/11 Loss D: 1.0863, Loss G: 2.4514
# Epoch [464/500] Batch 0/11 Loss D: 1.0123, Loss G: 1.7844
# Epoch [465/500] Batch 0/11 Loss D: 1.0610, Loss G: 1.5043
# Epoch [466/500] Batch 0/11 Loss D: 0.9647, Loss G: 2.3448
# Epoch [467/500] Batch 0/11 Loss D: 0.9880, Loss G: 1.5369
# Epoch [468/500] Batch 0/11 Loss D: 0.8970, Loss G: 1.4058
# Epoch [469/500] Batch 0/11 Loss D: 0.8921, Loss G: 1.8340
# Epoch [470/500] Batch 0/11 Loss D: 0.9135, Loss G: 2.3299
# Epoch [471/500] Batch 0/11 Loss D: 0.9486, Loss G: 1.9827
# Epoch [472/500] Batch 0/11 Loss D: 0.8220, Loss G: 1.8526
# Epoch [473/500] Batch 0/11 Loss D: 0.8948, Loss G: 1.2525
# Epoch [474/500] Batch 0/11 Loss D: 1.1775, Loss G: 2.4316
# Epoch [475/500] Batch 0/11 Loss D: 0.8710, Loss G: 2.3713
# Epoch [476/500] Batch 0/11 Loss D: 1.6640, Loss G: 3.7411
# Epoch [477/500] Batch 0/11 Loss D: 0.8471, Loss G: 1.4541
# Epoch [478/500] Batch 0/11 Loss D: 0.8427, Loss G: 1.4633
# Epoch [479/500] Batch 0/11 Loss D: 0.9062, Loss G: 1.8448
# Epoch [480/500] Batch 0/11 Loss D: 0.9449, Loss G: 1.9240
# Epoch [481/500] Batch 0/11 Loss D: 1.2407, Loss G: 2.6670
# Epoch [482/500] Batch 0/11 Loss D: 0.8721, Loss G: 1.1948
# Epoch [483/500] Batch 0/11 Loss D: 1.3703, Loss G: 2.6110
# Epoch [484/500] Batch 0/11 Loss D: 1.0946, Loss G: 2.0180
# Epoch [485/500] Batch 0/11 Loss D: 0.9983, Loss G: 1.6659
# Epoch [486/500] Batch 0/11 Loss D: 0.6985, Loss G: 1.7536
# Epoch [487/500] Batch 0/11 Loss D: 0.7701, Loss G: 1.7556
# Epoch [488/500] Batch 0/11 Loss D: 1.0250, Loss G: 1.8295
# Epoch [489/500] Batch 0/11 Loss D: 1.3083, Loss G: 2.5882
# Epoch [490/500] Batch 0/11 Loss D: 0.7984, Loss G: 1.4016
# Epoch [491/500] Batch 0/11 Loss D: 0.7663, Loss G: 1.8808
# Epoch [492/500] Batch 0/11 Loss D: 0.9239, Loss G: 1.6182
# Epoch [493/500] Batch 0/11 Loss D: 0.7390, Loss G: 2.2274
# Epoch [494/500] Batch 0/11 Loss D: 0.7829, Loss G: 2.1088
# Epoch [495/500] Batch 0/11 Loss D: 1.0877, Loss G: 2.1684
# Epoch [496/500] Batch 0/11 Loss D: 0.9809, Loss G: 2.0614
# Epoch [497/500] Batch 0/11 Loss D: 0.9415, Loss G: 2.1307
# Epoch [498/500] Batch 0/11 Loss D: 1.0325, Loss G: 1.7151
# Epoch [499/500] Batch 0/11 Loss D: 0.8956, Loss G: 1.8666
# Epoch [500/500] Batch 0/11 Loss D: 1.1549, Loss G: 2.9264
